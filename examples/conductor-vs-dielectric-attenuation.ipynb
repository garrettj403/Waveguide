# %% [markdown]
# # Waveguide Attenuation: Conductor vs Dielectric Loss
#
# This notebook will calculate the waveguide attenuation constant due to conductor loss and dielectric loss.
#
# The values will be calculated based on the approximate properties of an HDPE filled waveguide.

# %%
import numpy as np
import scipy.constants as sc
import matplotlib.pyplot as plt
import matplotlib as mpl

# https://github.com/garrettj403/Waveguide
from waveguide import conductor_loss, dielectric_loss
from waveguide import cutoff_frequency, np2db

# https://github.com/garrettj403/SciencePlots
plt.style.use(["science", "notebook"])

# %% [markdown]
# # Waveguide Sizes

# %%
# Waveguide sizes to analyze (EIA designations)
wr_sizes = np.array([28, 22.4, 18.8, 14.8, 12.2, 10, 6.5, 5.1, 4.3, 3.4, 2.8])
f_center = np.empty_like(wr_sizes)
f1 = np.empty_like(wr_sizes)
f2 = np.empty_like(wr_sizes)
dimensions = []

for i, _wr in np.ndenumerate(wr_sizes):
    
    a = _wr * 10 * sc.mil
    b = a / 2
    dimensions.append((a, b))
    
    f1[i] = cutoff_frequency(a, b, m=1, n=0)
    f2[i] = cutoff_frequency(a, b, m=2, n=0)
    f_center[i] = (f1[i] + f2[i]) / 2
    
    wr_name = "WR-{:.1f}".format(_wr)
    print("{:7}: {:5.1f} to {:5.1f} GHz, center = {:5.1f} GHz".format(wr_name, f1[i]*1.25/1e9, f2[i]*0.95/1e9, f_center[i]/1e9))
    
fig, ax = plt.subplots(figsize=(12,12))
ax.loglog(wr_sizes, f_center/1e9, 'ko')
ax.errorbar(wr_sizes, f_center/1e9, yerr=[(f_center-f1)/1e9, -(f_center-f2)/1e9], c='k', fmt='o', ls='--', capsize=5, capthick=2)
ax.set_xlabel("\nEIA waveguide designation (\"WR-\")")
ax.set_ylabel("Frequency range (GHz)")
ax.set_ylim([20, 500])
ax.grid(which='both')
plt.yticks(ticks=[20, 30, 40, 50, 60, 70, 80, 90, 100, 200, 300, 400, 500], labels=[20, 30, 40, 50, 60, 70, 80, 90, 100, 200, 300, 400, 500])
ax.set_xticks(ticks=wr_sizes, minor=False)
ax.set_xticks(ticks=[], minor=True)
plt.xticks(ticks=wr_sizes, labels=wr_sizes, rotation=90)
fig.savefig("results/waveguide-loss-cutoff-frequency.png", dpi=400);
# Out:
# WR-28.0:  26.3 to  40.0 GHz, center =  31.6 GHz
# WR-22.4:  32.9 to  50.1 GHz, center =  39.5 GHz
# WR-18.8:  39.2 to  59.6 GHz, center =  47.1 GHz
# WR-14.8:  49.8 to  75.8 GHz, center =  59.8 GHz
# WR-12.2:  60.5 to  91.9 GHz, center =  72.6 GHz
# WR-10.0:  73.8 to 112.1 GHz, center =  88.5 GHz
# WR-6.5 : 113.5 to 172.5 GHz, center = 136.2 GHz
# WR-5.1 : 144.6 to 219.9 GHz, center = 173.6 GHz
# WR-4.3 : 171.6 to 260.8 GHz, center = 205.9 GHz
# WR-3.4 : 217.0 to 329.8 GHz, center = 260.4 GHz
# WR-2.8 : 263.5 to 400.5 GHz, center = 316.1 GHz

# %% [markdown]
# # HDPE

# %% [markdown]
# ## Conductor Loss

# %%
# Relative permittivity
er = 2.3

# Conductivity of waveguide walls
conductivity_list = np.array([1.0e7, 2.0e7, 4.0e7, 8.0e7, 12.0e7])

plt.figure(figsize=(12,6))
plt.title(r"HDPE: Conductor Attenuation, $\alpha_c$")
for i, _cond in np.ndenumerate(conductivity_list):
    alpha_c = []
    for _fc, _dim in zip(f_center, dimensions):
        alpha_c.append(conductor_loss(_fc, _cond, _dim[0], _dim[1], er=er))
    alpha_c = np.array(alpha_c)
    plt.semilogy(f_center/1e9, np2db(alpha_c), marker='o', ls='--', label=r"${:.0f}\times10^7$".format(_cond/1e7))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_c), wr_sizes):
            plt.text(_f, _a*1.15, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.ylabel(r"Conductor Attenuation, $\alpha_c$ (dB/m)")
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.legend(title="Conductivity (S/m), $\sigma$")
plt.ylim([0.3, 110])
plt.savefig("results/waveguide-loss-hdpe-alphac.png", dpi=400);

# %% [markdown]
# ## Dielectric Loss

# %%
# Relative permittivity
er = 2.3

# Loss tangent
tand_list = [2e-4, 1e-4, 5e-5, 1e-5]

plt.figure(figsize=(12,6))
plt.title(r"HDPE: Dielectric Attenuation, $\alpha_d$")
for i, _tand in np.ndenumerate(tand_list):
    alpha_d = []
    _er = er * (1 - 1j * _tand)
    for _fc, _dim in zip(f_center, dimensions):
        alpha_d.append(dielectric_loss(_fc, _dim[0], b=_dim[1], er=_er))
    alpha_d = np.array(alpha_d)
    plt.plot(f_center/1e9, np2db(alpha_d), marker='o', ls='--', label=r"${:.1f}\times10^{{-4}}$".format(_tand*1e4))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_d), wr_sizes):
            plt.text(_f, _a+0.5, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.ylabel(r"Dielectric Attenuation, $\alpha_d$ (dB/m)")
plt.ylim([0, 12])
plt.legend(title=r"Loss tangent ($\tan\,\delta$)")
plt.savefig("results/waveguide-loss-hdpe-alphad.png", dpi=400);

# %% [markdown]
# # Ratio

# %%
# Relative permittivity
er = 2.3

# Conductivity
cond = 4e7
alpha_c = []
for _fc, _dim in zip(f_center, dimensions):
    alpha_c.append(conductor_loss(_fc, cond, _dim[0], _dim[1], er=er))
alpha_c = np.array(alpha_c)

# Loss tangent
tand_list = [2e-4, 1e-4, 5e-5, 1e-5]

plt.figure(figsize=(12,6))
plt.title(r"Room temperature HDPE cavity")
for i, _tand in np.ndenumerate(tand_list):
    alpha_d = []
    _er = er * (1 - 1j * _tand)
    for _fc, _dim in zip(f_center, dimensions):
        alpha_d.append(dielectric_loss(_fc, _dim[0], b=_dim[1], er=_er))
    alpha_d = np.array(alpha_d)
    plt.plot(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), marker='o', ls='--', label=r"${:.1f}\times10^{{-4}}$".format(_tand*1e4))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), wr_sizes):
            plt.text(_f, _a+1.5, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.ylabel(r"Relative attenuation: $\alpha_d - \alpha_c$ (dB/m)")
plt.ylim([-25, 10])
line1 = r"Loss tangent ($\tan\,\delta$)"
line2 = r"$\sigma={:.0f}\times10^7$ S/m".format(cond/1e7)
plt.legend(title="{}\n{}".format(line2, line1))
plt.savefig("results/waveguide-loss-hdpe-relative-300k.png", dpi=400);

# %%
# Relative permittivity
er = 2.3

# Conductivity
cond = 12e7
alpha_c = []
for _fc, _dim in zip(f_center, dimensions):
    alpha_c.append(conductor_loss(_fc, cond, _dim[0], _dim[1], er=er))
alpha_c = np.array(alpha_c)

# Loss tangent
tand_list = [2e-4, 1e-4, 5e-5, 1e-5]

plt.figure(figsize=(12,6))
plt.title(r"Cryogenic HDPE cavity")
for i, _tand in np.ndenumerate(tand_list):
    alpha_d = []
    _er = er * (1 - 1j * _tand)
    for _fc, _dim in zip(f_center, dimensions):
        alpha_d.append(dielectric_loss(_fc, _dim[0], b=_dim[1], er=_er))
    alpha_d = np.array(alpha_d)
    plt.plot(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), marker='o', ls='--', label=r"${:.1f}\times10^{{-4}}$".format(_tand*1e4))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), wr_sizes):
            plt.text(_f, _a+1.5, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.ylabel(r"Relative attenuation: $\alpha_d - \alpha_c$ (dB/m)")
plt.ylim([-25, 10])
line1 = r"Loss tangent ($\tan\,\delta$)"
line2 = r"$\sigma={:.0f}\times10^7$ S/m".format(cond/1e7)
plt.legend(title="{}\n{}".format(line2, line1))
plt.savefig("results/waveguide-loss-hdpe-relative-4k.png", dpi=400);

# %% [markdown]
# # Alumina

# %% [markdown]
# ## Conductor Loss

# %%
# Relative permittivity
er = 9.9

# Conductivity of waveguide walls
conductivity_list = np.array([1.0e7, 2.0e7, 4.0e7, 8.0e7, 12.0e7])

plt.figure(figsize=(12,6))
plt.title(r"Alumina: Conductor Attenuation, $\alpha_c$")
for i, _cond in np.ndenumerate(conductivity_list):
    alpha_c = []
    for _fc, _dim in zip(f_center, dimensions):
        alpha_c.append(conductor_loss(_fc, _cond, _dim[0], _dim[1], er=er))
    alpha_c = np.array(alpha_c)
    plt.semilogy(f_center/1e9, np2db(alpha_c), marker='o', ls='--', label=r"${:.0f}\times10^7$".format(_cond/1e7))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_c), wr_sizes):
            plt.text(_f, _a*1.15, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.ylabel(r"Conductor Attenuation, $\alpha_c$ (dB/m)")
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.legend(title="Conductivity (S/m), $\sigma$")
plt.ylim([0.7, 170])
plt.savefig("results/waveguide-loss-alumina-alphac.png", dpi=400);

# %% [markdown]
# ## Dielectric Loss

# %%
# Relative permittivity
er = 9.9

# Loss tangent
tand_list = [20e-4, 10e-4, 5e-4, 3e-4, 2e-4, 1e-4]

plt.figure(figsize=(12,6))
plt.title(r"Alumina: Dielectric Attenuation, $\alpha_d$")
for i, _tand in np.ndenumerate(tand_list):
    alpha_d = []
    _er = er * (1 - 1j * _tand)
    for _fc, _dim in zip(f_center, dimensions):
        alpha_d.append(dielectric_loss(_fc, _dim[0], b=_dim[1], er=_er))
    alpha_d = np.array(alpha_d)
    plt.plot(f_center/1e9, np2db(alpha_d), marker='o', ls='--', label=r"${:.0f}\times10^{{-4}}$".format(_tand*1e4))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_d), wr_sizes):
            plt.text(_f, _a+5, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.ylabel(r"Dielectric Attenuation, $\alpha_d$ (dB/m)")
plt.ylim([0, 230])
plt.legend(title=r"Loss tangent ($\tan\,\delta$)")
plt.savefig("results/waveguide-loss-alumina-alphad.png", dpi=400);

# %%
# Relative permittivity
er = 9.9

# Conductivity
cond = 4e7
alpha_c = []
for _fc, _dim in zip(f_center, dimensions):
    alpha_c.append(conductor_loss(_fc, cond, _dim[0], _dim[1], er=er))
alpha_c = np.array(alpha_c)

# Loss tangent
tand_list = [20e-4, 10e-4, 5e-4, 1e-4]

plt.figure(figsize=(12,6))
plt.title(r"Room temperature alumina cavity")
for i, _tand in np.ndenumerate(tand_list):
    alpha_d = []
    _er = er * (1 - 1j * _tand)
    for _fc, _dim in zip(f_center, dimensions):
        alpha_d.append(dielectric_loss(_fc, _dim[0], b=_dim[1], er=_er))
    alpha_d = np.array(alpha_d)
    plt.plot(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), marker='o', ls='--', label=r"${:.1f}\times10^{{-4}}$".format(_tand*1e4))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), wr_sizes):
            plt.text(_f, _a+5, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.ylabel(r"Relative attenuation: $\alpha_d - \alpha_c$ (dB/m)")
plt.ylim([-30, 200])
line1 = r"Loss tangent ($\tan\,\delta$)"
line2 = r"$\sigma={:.0f}\times10^7$ S/m".format(cond/1e7)
plt.legend(title="{}\n{}".format(line2, line1))
plt.savefig("results/waveguide-loss-alumina-relative-300k.png", dpi=400);

# %%
# Relative permittivity
er = 9.9

# Conductivity
cond = 12e7
alpha_c = []
for _fc, _dim in zip(f_center, dimensions):
    alpha_c.append(conductor_loss(_fc, cond, _dim[0], _dim[1], er=er))
alpha_c = np.array(alpha_c)

# Loss tangent
tand_list = [20e-4, 10e-4, 5e-4, 1e-4]

plt.figure(figsize=(12,6))
plt.title(r"Cryogenic alumina cavity")
for i, _tand in np.ndenumerate(tand_list):
    alpha_d = []
    _er = er * (1 - 1j * _tand)
    for _fc, _dim in zip(f_center, dimensions):
        alpha_d.append(dielectric_loss(_fc, _dim[0], b=_dim[1], er=_er))
    alpha_d = np.array(alpha_d)
    plt.plot(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), marker='o', ls='--', label=r"${:.0f}\times10^{{-4}}$".format(_tand*1e4))
    if i[0] == 0:
        for _f, _a, _wr in zip(f_center/1e9, np2db(alpha_d) - np2db(alpha_c), wr_sizes):
            plt.text(_f, _a+5, "WR-{:.1f}".format(_wr), ha='center', va='bottom', rotation=90)
plt.xlabel("Waveguide Center Frequency (GHz)")
plt.ylabel(r"Relative attenuation: $\alpha_d - \alpha_c$ (dB/m)")
plt.ylim([-30, 200])
line1 = r"Loss tangent ($\tan\,\delta$)"
line2 = r"$\sigma={:.0f}\times10^7$ S/m".format(cond/1e7)
plt.legend(title="{}\n{}".format(line2, line1))
plt.savefig("results/waveguide-loss-alumina-relative-4k.png", dpi=400);
